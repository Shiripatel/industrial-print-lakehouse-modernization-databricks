# %% [markdown]
# # 03 – Gold DWH Modeling
#
# This notebook builds simple **Gold layer** dimensional models for BI consumption.

# %%
spark.sql(open('/mnt/data/industrial-print-lakehouse-modernization-databricks/sql/create_gold_marts.sql').read())
